# %% [markdown]
# <a href="https://colab.research.google.com/github/wigneshh/NLP/blob/main/Assignment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Example text data (you can replace this with any larger corpus) text = """ Once upon a time, there was a little girl named Red Riding Hood. She loved to visit her grandmother, who lived in the woods. One day, her mother asked her to take a basket of goodies to her grandmother. On her way through the woods, she met a big bad wolf who wanted to eat her. [CO5]
# (i) Build the Transformer Model on above dataset
#
# (ii) Train the model using 20, 60, 70 epochs
#
#  (iii) After training, use the model to generate new text by feeding it an initial seed text
#
# (iv) Experimenting and Improving the Model by large dataset and hyper tune parameter.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding, MultiHeadAttention, LayerNormalization, Dense, Dropout
from tensorflow.keras import Sequential, Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

text = """Once upon a time, there was a little girl named Red Riding Hood. She loved to visit her grandmother, who lived in the woods. One day, her mother asked her to take a basket of goodies to her grandmother. On her way through the woods, she met a big bad wolf who wanted to eat her."""

vocab_size = 1000
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts([text])


sequences = tokenizer.texts_to_sequences([text])[0]


input_sequences = []
for i in range(1, len(sequences)):
    input_sequences.append(sequences[:i+1])


max_sequence_len = max(len(x) for x in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre')

X, y = input_sequences[:,:-1], input_sequences[:,-1]
y = tf.keras.utils.to_categorical(y, num_classes=vocab_size)


class TransformerModel(Model):
    def __init__(self, vocab_size, embed_dim, num_heads, ff_dim):
        super(TransformerModel, self).__init__()
        self.embedding = Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.attention = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = Sequential([Dense(ff_dim, activation="relu"), Dense(embed_dim)])
        self.layernorm1 = LayerNormalization()
        self.layernorm2 = LayerNormalization()
        self.dropout1 = Dropout(0.1)
        self.dropout2 = Dropout(0.1)
        self.final_layer = Dense(vocab_size, activation="softmax")

    def call(self, inputs):
        x = self.embedding(inputs)
        attn_output = self.attention(x, x)
        x = self.layernorm1(x + self.dropout1(attn_output))
        ffn_output = self.dense_proj(x)
        x = self.layernorm2(x + self.dropout2(ffn_output))
        return self.final_layer(x[:, -1])


embed_dim = 128
num_heads = 4
ff_dim = 512

transformer_model = TransformerModel(vocab_size, embed_dim, num_heads, ff_dim)
transformer_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])


epochs_list = [20,60,70]
for epochs in epochs_list:
    print(f"\nTraining model with {epochs} epochs:")
    transformer_model.fit(X, y, epochs=epochs, verbose=1)


def generate_text(model, tokenizer, seed_text, max_length=50):
    for _ in range(max_length):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len - 1, padding='pre')
        predicted = model.predict(token_list, verbose=0)
        predicted_word_index = np.argmax(predicted, axis=-1).item()
        output_word = tokenizer.index_word.get(predicted_word_index, "")
        seed_text += " " + output_word
    return seed_text


seed_text = "Once upon a time"
print("\nGenerated text:", generate_text(transformer_model, tokenizer, seed_text))
# Out:
# Training model with 20 epochs:
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.0000e+00 - loss: 7.0221
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.2288 - loss: 5.9813
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - accuracy: 0.2271 - loss: 5.3617
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.3085 - loss: 4.8367
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.4956 - loss: 4.2609
# Epoch 6/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 0.6239 - loss: 3.8384
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.7487 - loss: 3.3363
# Epoch 8/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7608 - loss: 2.9252
# Epoch 9/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7816 - loss: 2.4931
# Epoch 10/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7816 - loss: 2.1712
# Epoch 11/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.8025 - loss: 1.8503
# Epoch 12/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 0.7816 - loss: 1.6017
# Epoch 13/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 0.7608 - loss: 1.4193
# Epoch 14/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 0.7920 - loss: 1.2141
# Epoch 15/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 0.8042 - loss: 1.0658
# Epoch 16/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.7955 - loss: 0.9762
# Epoch 17/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8059 - loss: 0.9125
# Epoch 18/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.8475 - loss: 0.7164
# Epoch 19/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.8509 - loss: 0.7177
# Epoch 20/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.8509 - loss: 0.6410
#
# Training model with 60 epochs:
# Epoch 1/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9169 - loss: 0.5585
# Epoch 2/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9186 - loss: 0.5448
# Epoch 3/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.9081 - loss: 0.5152
# Epoch 4/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.9307 - loss: 0.5046
# Epoch 5/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9307 - loss: 0.4076
# Epoch 6/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 0.9098 - loss: 0.4558
# Epoch 7/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - accuracy: 0.9394 - loss: 0.3667
# Epoch 8/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8977 - loss: 0.4004
# Epoch 9/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - accuracy: 0.9307 - loss: 0.3836
# Epoch 10/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9081 - loss: 0.3341
# Epoch 11/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9098 - loss: 0.3517
# Epoch 12/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.8977 - loss: 0.3423
# Epoch 13/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8977 - loss: 0.3025
# Epoch 14/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9532 - loss: 0.3117
# Epoch 15/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - accuracy: 0.9290 - loss: 0.2505
# Epoch 16/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step - accuracy: 0.9081 - loss: 0.2773
# Epoch 17/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - accuracy: 0.9411 - loss: 0.2615
# Epoch 18/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 0.9203 - loss: 0.2314
# Epoch 19/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - accuracy: 0.9307 - loss: 0.2292
# Epoch 20/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9532 - loss: 0.2210
# Epoch 21/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9428 - loss: 0.2226
# Epoch 22/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9411 - loss: 0.1957
# Epoch 23/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9758 - loss: 0.1915
# Epoch 24/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9549 - loss: 0.2145
# Epoch 25/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9203 - loss: 0.2045
# Epoch 26/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.9098 - loss: 0.1931
# Epoch 27/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9428 - loss: 0.1941
# Epoch 28/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.9307 - loss: 0.1779
# Epoch 29/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 0.9307 - loss: 0.1756
# Epoch 30/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9549 - loss: 0.1651
# Epoch 31/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9879 - loss: 0.1512
# Epoch 32/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9307 - loss: 0.1563
# Epoch 33/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 0.9307 - loss: 0.1565
# Epoch 34/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9775 - loss: 0.1291
# Epoch 35/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9775 - loss: 0.1285
# Epoch 36/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - accuracy: 0.9775 - loss: 0.1315
# Epoch 37/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9758 - loss: 0.1197
# Epoch 38/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9653 - loss: 0.1264
# Epoch 39/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 238ms/step - accuracy: 0.9879 - loss: 0.1076
# Epoch 40/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - accuracy: 0.9879 - loss: 0.1195
# Epoch 41/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 255ms/step - accuracy: 1.0000 - loss: 0.1172
# Epoch 42/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 0.9775 - loss: 0.1124
# Epoch 43/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.9653 - loss: 0.1092
# Epoch 44/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9775 - loss: 0.1084
# Epoch 45/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9879 - loss: 0.0908
# Epoch 46/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9758 - loss: 0.0964
# Epoch 47/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.9775 - loss: 0.0951
# Epoch 48/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9549 - loss: 0.1173
# Epoch 49/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 0.9758 - loss: 0.1380
# Epoch 50/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9636 - loss: 0.1150
# Epoch 51/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step - accuracy: 0.9290 - loss: 0.1279
# Epoch 52/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9394 - loss: 0.1886
# Epoch 53/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9307 - loss: 0.2127
# Epoch 54/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.8960 - loss: 0.2603
# Epoch 55/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.8752 - loss: 0.3475
# Epoch 56/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.9758 - loss: 0.1133
# Epoch 57/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9428 - loss: 0.1977
# Epoch 58/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9775 - loss: 0.1178
# Epoch 59/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.9549 - loss: 0.1413
# Epoch 60/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9428 - loss: 0.1502
#
# Training model with 70 epochs:
# Epoch 1/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9532 - loss: 0.1438
# Epoch 2/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9428 - loss: 0.1234
# Epoch 3/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 289ms/step - accuracy: 0.9758 - loss: 0.1065
# Epoch 4/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - accuracy: 0.9428 - loss: 0.1124
# Epoch 5/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 0.9653 - loss: 0.0932
# Epoch 6/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 308ms/step - accuracy: 0.9758 - loss: 0.0753
# Epoch 7/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - accuracy: 1.0000 - loss: 0.0894
# Epoch 8/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9879 - loss: 0.1038
# Epoch 9/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9653 - loss: 0.0946
# Epoch 10/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9653 - loss: 0.0906
# Epoch 11/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9653 - loss: 0.0798
# Epoch 12/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.9879 - loss: 0.0751
# Epoch 13/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9879 - loss: 0.0747
# Epoch 14/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9775 - loss: 0.0802
# Epoch 15/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9879 - loss: 0.0709
# Epoch 16/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.9775 - loss: 0.0789
# Epoch 17/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9775 - loss: 0.0700
# Epoch 18/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.9879 - loss: 0.0570
# Epoch 19/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9879 - loss: 0.0565
# Epoch 20/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.9879 - loss: 0.0656
# Epoch 21/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - accuracy: 1.0000 - loss: 0.0573
# Epoch 22/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - accuracy: 0.9775 - loss: 0.0583
# Epoch 23/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9775 - loss: 0.0623
# Epoch 24/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9879 - loss: 0.0579
# Epoch 25/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9775 - loss: 0.0627
# Epoch 26/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0467
# Epoch 27/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9879 - loss: 0.0485
# Epoch 28/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 247ms/step - accuracy: 0.9879 - loss: 0.0478
# Epoch 29/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 340ms/step - accuracy: 0.9879 - loss: 0.0443
# Epoch 30/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - accuracy: 0.9775 - loss: 0.0580
# Epoch 31/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 0.9775 - loss: 0.0594
# Epoch 32/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 247ms/step - accuracy: 0.9775 - loss: 0.0654
# Epoch 33/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.9775 - loss: 0.0468
# Epoch 34/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 1.0000 - loss: 0.0370
# Epoch 35/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 1.0000 - loss: 0.0356
# Epoch 36/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 1.0000 - loss: 0.0460
# Epoch 37/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 1.0000 - loss: 0.0414
# Epoch 38/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 1.0000 - loss: 0.0425
# Epoch 39/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 1.0000 - loss: 0.0409
# Epoch 40/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0370
# Epoch 41/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0295
# Epoch 42/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 1.0000 - loss: 0.0294
# Epoch 43/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.9879 - loss: 0.0345
# Epoch 44/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.9879 - loss: 0.0304
# Epoch 45/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 0.0275
# Epoch 46/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 0.0296
# Epoch 47/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9775 - loss: 0.0377
# Epoch 48/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.9879 - loss: 0.0272
# Epoch 49/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 1.0000 - loss: 0.0259
# Epoch 50/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - accuracy: 1.0000 - loss: 0.0375
# Epoch 51/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - accuracy: 0.9879 - loss: 0.0320
# Epoch 52/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 303ms/step - accuracy: 0.9758 - loss: 0.0471
# Epoch 53/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - accuracy: 0.9653 - loss: 0.0470
# Epoch 54/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - accuracy: 0.9653 - loss: 0.0655
# Epoch 55/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - accuracy: 0.9653 - loss: 0.0727
# Epoch 56/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 216ms/step - accuracy: 0.9653 - loss: 0.1126
# Epoch 57/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9653 - loss: 0.1564
# Epoch 58/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9203 - loss: 0.3168
# Epoch 59/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.9758 - loss: 0.1390
# Epoch 60/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9203 - loss: 0.1497
# Epoch 61/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9203 - loss: 0.1820
# Epoch 62/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - accuracy: 0.9411 - loss: 0.1072
# Epoch 63/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8977 - loss: 0.1617
# Epoch 64/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9775 - loss: 0.1006
# Epoch 65/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.9879 - loss: 0.0808
# Epoch 66/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 0.9879 - loss: 0.0669
# Epoch 67/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0705
# Epoch 68/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9653 - loss: 0.0853
# Epoch 69/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.9653 - loss: 0.0804
# Epoch 70/70
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.9775 - loss: 0.0805
#
# Generated text: Once upon a time there was a little girl named red riding hood she loved to visit her grandmother who lived in the woods one day her mother asked her to take a basket of goodies to her grandmother on her way through the woods she met a big bad wolf who wanted to
